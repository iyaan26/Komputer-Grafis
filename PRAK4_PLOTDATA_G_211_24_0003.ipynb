# %% [markdown]
# <a href="https://colab.research.google.com/github/iyaan26/Komputer-Grafis/blob/main/PRAK4_PLOTDATA_G_211_24_0003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
DATAPLOT1
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,150,0,100])
plt.axis('on')
plt.grid(True)

x=np.arange(0,150,1)
y1=10+np.exp(.035*x)

plt.plot(x, y1,'b',label='y1')

plt.legend(loc='upper left')

plt.show()

# %%
"""
DATAPLOT2
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,150,0,100])
plt.axis('on')
plt.grid(True)

x=[20,40,60,80,100,120,140]
y1=[30,50,30,45,70,43,80]
y2=[45,35,40,60,60,55,70]

plt.plot(x,y1,'b',label='Temperature')
plt.plot(x,y2,'r',label='Pressure')

plt.legend(loc='upper left')

plt.scatter(x,y1,color='b',marker='s')
plt.scatter(x,y2,color='r',marker='*',s=50)

plt.show()

# %%
"""
DATAPLOT3
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,140,0,100])
plt.axis('on')
plt.grid(True)

t=[20,40,60,80,100,120,140]
T = [30, 33, 37.5, 44.5, 55.7, 70, 86]
P=[1.8,2.3,3,4,5.4,7.3,9.6]

plt.plot(t,T,color='r',label='Temperature')
plt.xlabel('Time')
plt.ylabel('Temperature',color='r')
plt.tick_params(axis='y',labelcolor='r')
plt.legend(loc='upper left')

plt.twinx()
plt.plot(t,P,color='b',label='Pressure')
plt.ylabel('Pressure',color='b')
plt.tick_params(axis='y',labelcolor='b')
plt.legend(loc='upper right')

plt.title('Test Results')

plt.show()

# %%
"""
DATAPLOT5
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,140,0,100])
plt.axis('on')
plt.grid(True)

t=[20,40,60,80,100,120]
T=[30,35,43,55,70,85]
p=[2,3,4.5,5.3,7.9,9.6]
v=[.6,.58,.54,.46,.35,.2]

pp=[ ]
for i in np.arange(0,len(p),1):
    pp.append(p[i]*10)

vv=[ ]
for i in np.arange(0,len(v),1):
    vv.append(v[i]*100)

plt.plot(t,T,color='r',label='Temperature',marker='o')
plt.plot(t,pp,color='b',label='Pressure',marker='s')
plt.plot(t,vv,color='g',label='Volume',marker='d')
plt.legend(loc='upper left')

for y in np.arange(0,100+1,20):
    a=y/10
    a=str(a)

# %%
"""
REGRESSION1
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,140,0,100])
plt.axis('on')
plt.grid(True)

t=[20,40,60,80,100,120]
T=[30,35,43,55,70,85]
p=[2,3,4.5,5.3,7.9,9.6]
v=[.6,.58,.54,.46,.35,.2]

pp=[ ]
for i in np.arange(0,len(p),1):
    pp.append(p[i]*10)

vv=[ ]
for i in np.arange(0,len(v),1):
    vv.append(v[i]*100)

plt.plot(t,T,color='r',label='Temperature',marker='o')
plt.plot(t,pp,color='b',label='Pressure',marker='s')
plt.plot(t,vv,color='g',label='Volume',marker='d')
plt.legend(loc='upper left')

for y in np.arange(0,100+1,20):
    a=y/10
    a=str(a)
n=len(v)

c1=np.sum(t)/n
c2=np.sum(v)/n
a=np.multiply(v,t)
c3=np.sum(a)
a=np.multiply(t,t)
c4=np.sum(a)

A=(c3-n*c1*c2)/(c4-n*c1*c1)
B=c2-A*c1

for tp in np.arange(t[0],t[5],2):
    vp=A*tp+B
    vp=vp*100
    plt.scatter(tp,vp,color='g',s=1)

sumee=0
for i in range(len(t)):
    ee=(v[i]-(A*t[i]+B))
    sumee=sumee+ee**2
    rms=np.sqrt(sumee/n)

plt.text(60, 28, 'v=At+B', color='g')
plt.arrow(78, 30, 6, 6, head_length=3, head_width=1.5, color='g', linewidth=.5)

vp1 = A * t[0] + B
vp1 = '%7.4f' % (vp1)
plt.text(2, 64, vp1, color='g')

vp2 = A * t[5] + B
vp2 = '%7.4f' % (vp2)
plt.text(122, 25, vp2, color='g')

Ap = '%7.5f' % (A)
plt.text(65, 18, 'A=', color='g')
plt.text(72, 18, Ap, color='g')

Bp = '%7.5f' % (B)
plt.text(65, 12, 'B=', color='g')
plt.text(73, 12, Bp, color='g')

rms = '%7.3f' % (rms)
plt.text(95, 3, 'RMS error=', color='g')
plt.text(123, 3, rms, color='g')

plt.show()
